# %% [markdown]
# <a href="https://colab.research.google.com/github/srujanatejavalli/FMML-COURSE-ASSIGNMENT/blob/main/module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 14:45:33--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   184MB/s    in 0.4s
#
# 2024-03-31 14:45:34 (184 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7317   1711.09294v1  We present the first adaptive strategy for act...  stat
# 21553   1009.2718v1  We present surrogate regret bounds for arbitra...  stat
# 22062   1409.4005v1  This paper studies ordered weighted L1 (OWL) n...  stat
# 16946  1707.05967v2  In this paper, we introduce a new distribution...    cs
# 13859  1511.08366v1  Today artificial neural networks are applied i...    cs
# ...             ...                                                ...   ...
# 20012   1312.6105v1  Recently, researchers in answer set programmin...    cs
# 16019  1608.03995v1  Topic models make strong assumptions about the...    cs
# 33178  1803.02991v1  We present a VAE architecture for encoding and...    cs
# 22124  1501.00725v1  We consider the problem of unveiling the impli...  stat
# 29855  1710.09933v1  The quantitative analysis of 3D confocal micro...    cs
#
#                                                    title  year  \
# 7317   An Adaptive Strategy for Active Learning with ...  2017
# 21553  Calibrated Surrogate Losses for Classification...  2010
# 22062  Sparse Estimation with Strongly Correlated Var...  2014
# 16946  Measuring Thematic Fit with Distributional Fea...  2017
# 13859  On randomization of neural networks as a form ...  2015
# ...                                                  ...   ...
# 20012  Hybrid Automated Reasoning Tools: from Black-b...  2013
# 16019           Analysis of Morphology in Topic Modeling  2016
# 33178  A Deep Generative Model for Disentangled Repre...  2018
# 22124  A generalization error bound for sparse and lo...  2015
# 29855  SEGMENT3D: A Web-based Application for Collabo...  2017
#
#                                                 keywords
# 7317   [classification, adaptivity, distributional, e...
# 21553  [surrogate, arbitrary, surrogate, classificati...
# 22062  [regularization, estimation, correlated, varia...
# 16946  [introduce, distributional, predicate, judgmen...
# 13859  [artificial, engineering, represent, successfu...
# ...                                                  ...
# 20012  [researchers, programming, constraint, program...
# 16019  [assumptions, particular, different, implicitl...
# 33178  [architecture, generating, dimensional, sequen...
# 22124  [unveiling, structure, interactions, frequency...
# 29855  [quantitative, microscopy, understanding, segm...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7317     [classification, adaptivity, distributional, e...
# 21553    [surrogate, arbitrary, surrogate, classificati...
# 22062    [regularization, estimation, correlated, varia...
# 16946    [introduce, distributional, predicate, judgmen...
# 13859    [artificial, engineering, represent, successfu...
#                                ...
# 14123    [successfully, translation, manufacturing, rec...
# 6615     [compositional, nonparametric, expressed, summ...
# 27577    [fundamental, knowledge, appearance, informati...
# 21986    [demonstrated, theoretical, guarantees, availa...
# 36045    [programming, increasingly, framework, declara...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8840 words.
# Out of those 4624 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5852d22f-5c7a-4065-a7c5-57f4175c7aaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5852d22f-5c7a-4065-a7c5-57f4175c7aaf")) {                    Plotly.newPlot(                        "5852d22f-5c7a-4065-a7c5-57f4175c7aaf",                        [{"x":["parameters","adaptivity","distributional","practical","reduction","established","univariate","combining","strategies","multivariate","establish","knowledge","classification","characterize","precisely","classifiers","sensitive","satisfies","framework","calibrated","condition","approaches","exponential","insensitive","functions","calibration","arbitrary","nontrivial","surrogate","generalization","developed","dependent","statistical","performance","regardless","completely","generative","regression","sufficient","different","clustering","coefficients","uncorrelated","variables","dimensional","assumptions","measurements","conditions","accurately","particular","independent","generating","estimation","regularization","furthermore","correlated","introduce","unsupervised","consistently","characterizing","comparable","prototypes","measuring","judgments","dimensions","implementing","candidate","representation","outperforms","predicate","experiments","literature","prototypical","randomization","applications","mathematically","relatively","numerical","conclusive","presented","technique","occurring","represent","sometimes","configuration","therefore","artificial","engineering","effective","computational","successful","interpolated","convolutional","decompositions","parametrizations","convolution","dictionary","irregularly","information","negativity","principal","classical","multimodal","optimally","outperform","processing","resolution","altimeter","component","constraints","application","enhancement","especially","demonstrate","reconstructions","relevance","investigate","interpolation","temperature","reconstruction","eigenspectrum","experimentally","determination","correspondence","eigenvector","descriptor","curvature","preserved","descriptors","transformation","commutative","characterization","isometric","decomposition","computation","resulting","inclusive","difference","recognition","alternating","overfitting","approximate","regularize","optimizing","experimental","identities","approximately","iteratively","insufficient","objective","difficulties","alleviate","significantly","challenge","modalities","heterogeneous","homogeneous","clustered","constraint","variational","minimization","formulation","introduced","challenging","development","outstanding","inevitable","robustness","promising","interpreting","categories","impressive","integration","automatic","extraction","extracting","categorization","applicability","annotations","automatically","evaluated","differences","specifically","elaborate","detection","ingenious","requirements","handcrafted","hierarchical","available","surprising","constrains","recognize","transferred","orientation","hyperplane","favorable","generalize","imagination","transferring"],"y":[249,5,25,128,95,42,9,101,112,25,54,344,507,48,27,124,48,14,514,8,49,431,48,6,201,20,80,7,14,103,194,75,145,860,15,40,123,131,54,762,158,40,4,128,192,72,49,128,67,286,138,98,205,84,167,39,324,146,44,15,98,8,30,13,48,21,44,371,257,11,607,136,7,5,401,10,55,96,5,162,250,14,105,31,28,149,108,58,265,313,87,2,376,7,1,43,50,2,695,3,33,106,38,16,91,297,133,1,98,128,245,26,133,566,7,45,126,12,2,92,1,52,23,31,7,36,12,17,50,65,1,27,3,67,153,146,2,68,395,30,26,101,10,43,378,10,34,42,16,159,26,31,274,160,40,36,14,8,93,58,67,78,124,304,132,8,6,121,118,12,59,16,51,198,118,51,19,46,56,182,151,58,163,7,353,1,52,16,102,302,7,7,46,12,28,4,8,67,3,8],"type":"bar"},{"x":["parameters","adaptivity","d ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4624,), (4624, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8191666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3803418803418804);'>Statistical</span> <span style=''>Approach</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Continuous</span> <span style=''>Self</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Calibrating</span> <span style=''>Eye</span> <span style=''>Gaze</span> <span style=''>Tracking</span> <span style=''>for</span> <span style=''>Head</span> <span style=''>Mounted</span> <span style=''>Virtual</span> <span style=''>Reality</span> <span style=''>Systems</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.546875);'>automatic</span> <span style=''>eye</span> <span style=''>gaze</span> <span style=''>tracking</span> <span style=''>scheme</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>smooth</span> <span style=''>pursuit</span> <span style=''>eye</span> <span style=''>motion</span> <span style=''>while</span> <span style=''>playing</span> <span style=''>mobile</span> <span style=''>games</span> <span style=''>or</span> <span style=''>watching</span> <span style=''>virtual</span> <span style=''>reality</span> <span style=''>contents</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>continuously</span> <span style=''>calibrates</span> <span style=''>an</span> <span style=''>eye</span> <span style=''>tracking</span> <span style=''>system</span> <span style=''>for</span> <span style=''>a</span> <span style=''>head</span> <span style=''>mounted</span> <span style=''>display</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>eliminates</span> <span style=''>the</span> <span style=''>need</span> <span style=''>for</span> <span style=''>an</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>calibration</span> <span style=''>step</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>automatically</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>compensates</span> <span style=''>for</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>movements</span> <span style=''>of</span> <span style=''>the</span> <span style=''>headset</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>the</span> <span style=''>head</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>finds</span> <span style='background-color:rgba(0, 255, 0, 0.846153846153846);'>correspondences</span> <span style=''>between</span> <span style=''>corneal</span> <span style=''>motion</span> <span style=''>and</span> <span style=''>screen</span> <span style=''>space</span> <span style=''>motion</span> <span style=''>and</span> <span style=''>uses</span> <span style=''>these</span> <span style=''>to</span> <span style=''>generate</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(255, 0, 0, 0.46311475409836067);'>Regression</span> <span style=''>models</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.32323232323232326);'>combination</span> <span style=''>of</span> <span style=''>those</span> <span style=''>models</span> <span style=''>provides</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>mapping</span> <span style=''>from</span> <span style=''>corneal</span> <span style=''>position</span> <span style=''>to</span> <span style=''>screen</span> <span style=''>space</span> <span style=''>position</span> <span style=''>Accu ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Engineering</span> <span style=''>Safety</span> <span style=''>in</span> <span style=''>Machine</span> <span style=''>Learning</span> <br/><br/><span style=''>Machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasingly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influencing</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decisions</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interacting</span> <span style=''>with</span> <span style=''>us</span> <span style=''>in</span> <span style=''>all</span> <span style=''>parts</span> <span style=''>of</span> <span style=''>our</span> <span style=''>daily</span> <span style=''>lives</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>just</span> <span style=''>like</span> <span style=''>for</span> <span style=''>power</span> <span style=''>plants</span> <span style=''>highways</span> <span style=''>and</span> <span style=''>myriad</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineered</span> <span style=''>sociotechnical</span> <span style=''>systems</span> <span style=''>we</span> <span style=''>must</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>safety</span> <span style=''>of</span> <span style=''>systems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>involving</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>first</span> <span style=''>discuss</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definition</span> <span style=''>of</span> <span style=''>safety</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>epistemic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>and</span> <span style=''>the</span> <span style=''>harm</span> <span style=''>incurred</span> <span style=''>by</span> <span style=''>unwanted</span> <span style=''>outcomes</span> <span style=''>Then</span> <span style=''>we</span> <span style=''>examine</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriateness</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>average</span> <span style=''>training</span> <span style=''>cost</span> <span style=''>along</span> <span style=''>which</span> <span style=''>certain</span> <span style=''>real</span> <span style=''>world</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>may</span> <span style=''>not</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completely</span> <span style=''>amenable</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>foundational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>of</span> <span style=''>modern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>machine</span> <span style=''>learning</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generalized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Eigenvector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Computation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Canonical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Correlation</span> <span style=''>Analysis</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considers</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>canonical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style=''>analysis</span> <span style=''>(CCA)</span> <span style=''>(Hotelling</span> <span style=''>1936)</span> <span style=''>and</span> <span style=''>more</span> <span style=''>broadly</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenvector</span> <span style=''>problem</span> <span style=''>for</span> <span style=''>a</span> <span style=''>pair</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>symmetric</span> <span style=''>matrices</span> <span style=''>These</span> <span style=''>are</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scientific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>with</span> <span style=''>numerous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistics</span> <span style=''>(Shi</span> <span style=''>and</span> <span style=''>Malik</span> <span style=''>2000</span> <span style=''>Hardoon</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2004</span> <span style=''>Witten</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2009)</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>improved</span> <span style=''>runtimes</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>that</span> <span style=''>are</span> <span style=''>globally</span> <span style=''>linearly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergent</span> <span style=''>with</span> <span style=''>moderate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependencies</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>condition</span> <span style=''>numbers</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.6521739130434783);'>eigenvalue</span> <span style=''>gaps</span> <span style=''>of</span> <span style=''>the</span> <span style=''>matrices</span> <span style=''>involved</span> <span style=''>We</span> <span style=''>obtain</span> <span style=''>our</span> <span style=''>results</span> <span style=''>by</span> <span style=''>reducing</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hypothesis</span> <span style=''>Testing</span> <span style=''>in</span> <span style=''>Pattern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Discovery</span> <br/><br/><span style=''>The</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>testing</span> <span style=''>arises</span> <span style=''>when</span> <span style=''>there</span> <span style=''>are</span> <span style=''>more</span> <span style=''>than</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>to</span> <span style=''>be</span> <span style=''>tested</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significance</span> <span style=''>This</span> <span style=''>is</span> <span style=''>a</span> <span style=''>very</span> <span style=''>common</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situation</span> <span style=''>in</span> <span style=''>many</span> <span style=''>data</span> <span style=''>mining</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>For</span> <span style=''>instance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assessing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significance</span> <span style=''>of</span> <span style=''>all</span> <span style=''>frequent</span> <span style=''>itemsets</span> <span style=''>of</span> <span style=''>a</span> <span style=''>single</span> <span style=''>dataset</span> <span style=''>entails</span> <span style=''>a</span> <span style=''>host</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>one</span> <span style=''>for</span> <span style=''>each</span> <span style=''>itemset</span> <span style=''>A</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>testing</span> <span style=''>method</span> <span style=''>is</span> <span style=''>needed</span> <span style=''>to</span> <span style=''>control</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>false</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>positives</span> <span style=''>(Type</span> <span style=''>I</span> <span style=''>error)</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contribution</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span style=''>with</span> <span style=''>a</span> <span style=''>generic</span> <span style=''>data</span> <span style=''>mining</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>method</span> <span style=''>that</span> <span style=''>provably</span> <span style=''>controls</span> <span style=''>the</span> <span style=''>family</span> <span style=''>wise</span> <span style=''>error</span> <span style=''>rate</span> <span style=''>(FWER</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabili ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.1356297093649085)
# 	knowledge (0.1234302116971654)
# 	segmentation (0.0739146035163258)
# 	representation (0.13311804808037317)
# 	architecture (0.0950843200574094)
# 	challenging (0.1090778614998206)
# 	detection (0.126659490491568)
# 	different (0.27341227125941875)
# 	convolutional (0.13491209185504127)
# 	recognition (0.14172945819878005)
#
# Some Statistics words are:
# 	stochastic (0.13015399900645802)
# 	variables (0.13611525086934922)
# 	theoretical (0.15250869349230006)
# 	distribution (0.17784401390958768)
# 	estimation (0.17635370094386488)
# 	algorithm (0.39244908097367115)
# 	statistical (0.16045702930948832)
# 	inference (0.19324391455538997)
# 	dimensional (0.19324391455538997)
# 	regression (0.17734724292101342)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7d7a3309-0592-47e4-a9b7-57a48def5763" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d7a3309-0592-47e4-a9b7-57a48def5763")) {                    Plotly.newPlot(                        "7d7a3309-0592-47e4-a9b7-57a48def5763",                        [{"x":["parameters","adaptivity","distributional","practical","reduction","established","univariate","combining","strategies","multivariate","establish","knowledge","classification","characterize","precisely","classifiers","sensitive","satisfies","framework","calibrated","condition","approaches","exponential","insensitive","functions","calibration","arbitrary","nontrivial","surrogate","generalization","developed","dependent","statistical","performance","regardless","completely","generative","regression","sufficient","different","clustering","coefficients","uncorrelated","variables","dimensional","assumptions","measurements","conditions","accurately","particular","independent","generating","estimation","regularization","furthermore","correlated","introduce","unsupervised","consistently","characterizing","comparable","prototypes","measuring","judgments","dimensions","implementing","candidate","representation","outperforms","predicate","experiments","literature","prototypical","randomization","applications","mathematically","relatively","numerical","conclusive","presented","technique","occurring","represent","sometimes","configuration","therefore","artificial","engineering","effective","computational","successful","interpolated","convolutional","decompositions","parametrizations","convolution","dictionary","irregularly","information","negativity","principal","classical","multimodal","optimally","outperform","processing","resolution","altimeter","component","constraints","application","enhancement","especially","demonstrate","reconstructions","relevance","investigate","interpolation","temperature","reconstruction","eigenspectrum","experimentally","determination","correspondence","eigenvector","descriptor","curvature","preserved","descriptors","transformation","commutative","characterization","isometric","decomposition","computation","resulting","inclusive","difference","recognition","alternating","overfitting","approximate","regularize","optimizing","experimental","identities","approximately","iteratively","insufficient","objective","difficulties","alleviate","significantly","challenge","modalities","heterogeneous","homogeneous","clustered","constraint","variational","minimization","formulation","introduced","challenging","development","outstanding","inevitable","robustness","promising","interpreting","categories","impressive","integration","automatic","extraction","extracting","categorization","applicability","annotations","automatically","evaluated","differences","specifically","elaborate","detection","ingenious","requirements","handcrafted","hierarchical","available","surprising","constrains","recognize","transferred","orientation","hyperplane","favorable","generalize","imagination","transferring","estimates","decisions","predictive","structure","covariance","discoveries","performances","interpretable","discovering","decomposing","manufacturing","administrative","capturing","important","competitive","synthetic","analyzing","explainable","appropriate","algorithm","conducted","comparison","components","exploiting","processes","frequency","dependence","astronomy","properties","following","separated","dimension","exponentially","separation","complexity","desirable","elementary","recovering","quantities","euclidean","obtaining","superposition","procedures","guarantees","spectroscopy","corrupted","concentration","procedure","algorithms","polynomially","polynomial","frequencies","in ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	byzantine
# 	physiologic
# 	preconditioning
# 	preconditioned
# 	bhattacharyya
# 	underdetermined
# 	repulsion
# 	datapoints
# 	delineates
# 	transposable
# 	distributionally
# 	coincides
# 	eigenstructures
# 	expectimax
# 	marginalize
# 	correntropy
# 	unscented
# 	lindenstrauss
# 	nonparametrics
# 	tsybakovs
# Some words which never appear in Statistics papers:
# 	inclusive
# 	imagination
# 	illumination
# 	discretize
# 	barycenter
# 	exchanging
# 	possibilistic
# 	backtrack
# 	formalisms
# 	photographic
# 	explainability
# 	negotiation
# 	deficiency
# 	humanities
# 	plurality
# 	epidemiological
# 	insertion
# 	executions
# 	manipulation
# 	processor

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077491229149997e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7733333333333333
